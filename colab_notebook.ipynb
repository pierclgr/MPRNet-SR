# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pierclgr/MPRNet-SR/blob/master/colab_notebook.ipynb)
#
# # MPRNet: Multi-Path Residual Network for Lightweight Image Super Resolution

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')

# clone the repo
# !echo "Cloning repo..."
# !git clone https://www.github.com/pierclgr/MPRNet-SR.git

# run the colab prepare script
# !echo "Preparing for training..."
# !bash MPRNet-SR/src/shell_scripts/colab_prepare.sh

# %%
# run training
# !cd MPRNet-SR && python src/trainer.py --config-name=colab_training seed=1508 optimizer.halving_steps=400000

# %%
# run testing
# !cd MPRNet-SR && python src/tester.py --config-name=colab_testing seed=1507 test_dataset.path=/content/MPRNet-SR/data/div2k/validation/hr/ testing.mode=model test_dataset.degradation=bicubic test_dataset.scale=4 wandb.run_name=Test_MPRNet_div2k_val_x4
